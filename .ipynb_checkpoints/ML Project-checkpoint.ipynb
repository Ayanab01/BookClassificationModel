# %% [markdown]
# <h1 style="font-size:3rem;color:Black;">Book Classification Model</h1>

# %% [markdown]
# # Machine Learning Project
#
# ## Project Summary
#
# ### “There is no friend as loyal as a book.” - Ernest Hemingway
#
# The aim of this Machine Learning (ML) Project is to train a machine learning model that is capable of predicting a book's rating.
#
# The Project is dividied into 4 Main Sections;
#
# - Data Analysis
#     - Data Extraction & Cleaning
#     - Data Wrangling & Analysis
#     - Plots & Relevant Histograms
#
# - Data Exploration & Feature Selection
#     - Feature Engineering
#
#
# - Model Training
#     - Comparison of different models
#
# - Model Evaluation
# - Data Visualisation & Analysis
#
# The dataset used for the project is a curation of Goodreads books based on real user information. Below is the information you have regarding the dataset attributes:
#
# 1) bookID: A unique identification number for each book.
#
# 2) title: The name under which the book was published.
#
# 3) authors: The names of the authors of the book. Multiple authors are delimited by “/”.
#
# 4) average_rating: The average rating of the book received in total.
#
# 5) isbn: Another unique number to identify the book, known as the International Standard Book Number.
#
# 6) isbn13: A 13-digit ISBN to identify the book, instead of the standard 11-digit ISBN.
#
# 7) language_code: Indicates the primary language of the book. For instance, “eng” is standard for English.
#
# 8) num_pages: The number of pages the book contains.
#
# 9) ratings_count: The total number of ratings the book received.
#
# 10) text_reviews_count: The total number of written text reviews the book received.
#
# 11) publication_date: The date the book was published.
#
# 12) publisher: The name of the book publisher.

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# To Begin, all the relevant packages that will be used (and have been installed) will be imported.

# %%
# All Imports
import os
import pandas as pd
import numpy as np
import sklearn as sk
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
from scipy.stats import norm
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# %% [markdown]
# ### Data Extraction

# %% [markdown]
# Lets Load the csv file into a pandas frame and check the shape of the dataframe.

# %%
df = pd.read_csv("C:/Users/Ayanaba/Documents/DSTI/Pyhton/Project/books.csv",  on_bad_lines='skip')
print("The data contains {0} Rows and {1} Columns".format(df.shape[0],df.shape[1]))
# Out:
# The data contains 11123 Rows and 12 Columns

# %%
# The data contains erroneous rows that have extra values; 
#'on_bad_lines' fucntion is used to skip there erroneous cases from our dataframe

# %% [markdown]
# ### Data Cleaning

# %%
#print column names
print("Column names: {0}".format(list(df.columns)))
# Out:
# Column names: ['bookID', 'title', 'authors', 'average_rating', 'isbn', 'isbn13', 'language_code', '  num_pages', 'ratings_count', 'text_reviews_count', 'publication_date', 'publisher']

# %% [markdown]
# First, lets take a look at the first  and last 10 rows of the dataframe.

# %%
df.shape
# Out:
# (11123, 12)

# %%
df.head(10)
# Out:
#    bookID                                              title  \
# 0       1  Harry Potter and the Half-Blood Prince (Harry ...
# 1       2  Harry Potter and the Order of the Phoenix (Har...
# 2       4  Harry Potter and the Chamber of Secrets (Harry...
# 3       5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4       8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 5       9  Unauthorized Harry Potter Book Seven News: "Ha...
# 6      10       Harry Potter Collection (Harry Potter  #1-6)
# 7      12  The Ultimate Hitchhiker's Guide: Five Complete...
# 8      13  The Ultimate Hitchhiker's Guide to the Galaxy ...
# 9      14  The Hitchhiker's Guide to the Galaxy (Hitchhik...
#
#                       authors  average_rating        isbn         isbn13  \
# 0  J.K. Rowling/Mary GrandPré            4.57  0439785960  9780439785969
# 1  J.K. Rowling/Mary GrandPré            4.49  0439358078  9780439358071
# 2                J.K. Rowling            4.42  0439554896  9780439554893
# 3  J.K. Rowling/Mary GrandPré            4.56  043965548X  9780439655484
# 4  J.K. Rowling/Mary GrandPré            4.78  0439682584  9780439682589
# 5      W. Frederick Zimmerman            3.74  0976540606  9780976540601
# 6                J.K. Rowling            4.73  0439827604  9780439827607
# 7               Douglas Adams            4.38  0517226952  9780517226957
# 8               Douglas Adams            4.38  0345453743  9780345453747
# 9               Douglas Adams            4.22  1400052920  9781400052929
#
#   language_code    num_pages  ratings_count  text_reviews_count  \
# 0           eng          652        2095690               27591
# 1           eng          870        2153167               29221
# 2           eng          352           6333                 244
# 3           eng          435        2339585               36325
# 4           eng         2690          41428                 164
# 5         en-US          152             19                   1
# 6           eng         3342          28242                 808
# 7           eng          815           3628                 254
# 8           eng          815         249558                4080
# 9           eng          215           4930                 460
#
#   publication_date        publisher
# 0        9/16/2006  Scholastic Inc.
# 1         9/1/2004  Scholastic Inc.
# 2        11/1/2003       Scholastic
# 3         5/1/2004  Scholastic Inc.
# 4        9/13/2004       Scholastic
# 5        4/26/2005     Nimble Books
# 6        9/12/2005       Scholastic
# 7        11/1/2005   Gramercy Books
# 8        4/30/2002    Del Rey Books
# 9         8/3/2004            Crown

# %%
df.tail(10)
# Out:
#        bookID                                              title  \
# 11113   45617  O Cavalo e o Seu Rapaz (As Crónicas de Nárnia ...
# 11114   45623   O Sobrinho do Mágico (As Crónicas de Nárnia  #1)
# 11115   45625  A Viagem do Caminheiro da Alvorada (As Crónica...
# 11116   45626     O Príncipe Caspian (As Crónicas de Nárnia  #4)
# 11117   45630                                  Whores for Gloria
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 11113        C.S. Lewis/Pauline Baynes/Ana Falcão Bastos            3.92
# 11114        C.S. Lewis/Pauline Baynes/Ana Falcão Bastos            4.04
# 11115        C.S. Lewis/Pauline Baynes/Ana Falcão Bastos            4.09
# 11116        C.S. Lewis/Pauline Baynes/Ana Falcão Bastos            3.97
# 11117                                William T. Vollmann            3.69
# 11118  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11119                                William T. Vollmann            4.08
# 11120                                William T. Vollmann            3.96
# 11121                                William T. Vollmann            3.72
# 11122                                         Mark Twain            3.91
#
#              isbn         isbn13 language_code    num_pages  ratings_count  \
# 11113  9722330551  9789722330558           por          160            207
# 11114  9722329987  9789722329989           por          147            396
# 11115  9722331329  9789722331326           por          176            161
# 11116  9722330977  9789722330978           por          160            215
# 11117  0140231579  9780140231571         en-US          160            932
# 11118  1560254416  9781560254416           eng          512            156
# 11119  0140110879  9780140110876           eng          635            783
# 11120  0140131965  9780140131963           eng          415            820
# 11121  0060878827  9780060878825           eng          434            769
# 11122  8497646983  9788497646987           spa          272            113
#
#        text_reviews_count publication_date           publisher
# 11113                  16        8/15/2003  Editorial Presença
# 11114                  37         4/8/2003  Editorial Presença
# 11115                  14         9/1/2004  Editorial Presença
# 11116                  11       10/11/2003  Editorial Presença
# 11117                 111         2/1/1994       Penguin Books
# 11118                  20       12/21/2004       Da Capo Press
# 11119                  56        12/1/1988       Penguin Books
# 11120                  95         8/1/1993       Penguin Books
# 11121                 139        2/27/2007                Ecco
# 11122                  12        5/28/2006       Edimat Libros

# %% [markdown]
# Next, lets check if the dataframe has any null values

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# The dataframe is clean, no null values were found.

# %% [markdown]
# ### Data Wrangling & Analysis

# %%
#Obtaining column information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11123 entries, 0 to 11122
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   bookID              11123 non-null  int64
#  1   title               11123 non-null  object
#  2   authors             11123 non-null  object
#  3   average_rating      11123 non-null  float64
#  4   isbn                11123 non-null  object
#  5   isbn13              11123 non-null  int64
#  6   language_code       11123 non-null  object
#  7     num_pages         11123 non-null  int64
#  8   ratings_count       11123 non-null  int64
#  9   text_reviews_count  11123 non-null  int64
#  10  publication_date    11123 non-null  object
#  11  publisher           11123 non-null  object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# The results show that 6 of the variables are numerical (int64 or float64). Those 6 variables can be considered as continous and 'described'. We also see that 'num_pages' has unwanted spaces in its name.

# %%
df = df.rename(columns={'  num_pages': 'num_pages'})

# %%
continuousVars = ['bookID', 'average_rating', 'isbn13', 'num_pages', 'ratings_count', 'text_reviews_count']
df[continuousVars].describe()
# Out:
#              bookID  average_rating        isbn13     num_pages  \
# count  11123.000000    11123.000000  1.112300e+04  11123.000000
# mean   21310.856963        3.934075  9.759880e+12    336.405556
# std    13094.727252        0.350485  4.429758e+11    241.152626
# min        1.000000        0.000000  8.987060e+09      0.000000
# 25%    10277.500000        3.770000  9.780345e+12    192.000000
# 50%    20287.000000        3.960000  9.780582e+12    299.000000
# 75%    32104.500000        4.140000  9.780872e+12    416.000000
# max    45641.000000        5.000000  9.790008e+12   6576.000000
#
#        ratings_count  text_reviews_count
# count   1.112300e+04        11123.000000
# mean    1.794285e+04          542.048099
# std     1.124992e+05         2576.619589
# min     0.000000e+00            0.000000
# 25%     1.040000e+02            9.000000
# 50%     7.450000e+02           47.000000
# 75%     5.000500e+03          238.000000
# max     4.597666e+06        94265.000000

# %% [markdown]
# From the continuous variables in the df, informed reasoning suggets that; 'bookID' and 'isbn13' will have no significant due to the nature and prupose of their existence.

# %%
# Drop columns with minor relevance towards ML prediction model
df.drop(columns = ['bookID','isbn13'])
# Out:
#                                                    title  \
# 0      Harry Potter and the Half-Blood Prince (Harry ...
# 1      Harry Potter and the Order of the Phoenix (Har...
# 2      Harry Potter and the Chamber of Secrets (Harry...
# 3      Harry Potter and the Prisoner of Azkaban (Harr...
# 4      Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...                                                  ...
# 11118   Expelled from Eden: A William T. Vollmann Reader
# 11119                        You Bright and Risen Angels
# 11120                    The Ice-Shirt (Seven Dreams #1)
# 11121                                        Poor People
# 11122                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# 1                             J.K. Rowling/Mary GrandPré            4.49
# 2                                           J.K. Rowling            4.42
# 3                             J.K. Rowling/Mary GrandPré            4.56
# 4                             J.K. Rowling/Mary GrandPré            4.78
# ...                                                  ...             ...
# 11118  William T. Vollmann/Larry McCaffery/Michael He...            4.06
# 11119                                William T. Vollmann            4.08
# 11120                                William T. Vollmann            3.96
# 11121                                William T. Vollmann            3.72
# 11122                                         Mark Twain            3.91
#
#              isbn language_code  num_pages  ratings_count  text_reviews_count  \
# 0      0439785960           eng        652        2095690               27591
# 1      0439358078           eng        870        2153167               29221
# 2      0439554896           eng        352           6333                 244
# 3      043965548X           eng        435        2339585               36325
# 4      0439682584           eng       2690          41428                 164
# ...           ...           ...        ...            ...                 ...
# 11118  1560254416           eng        512            156                  20
# 11119  0140110879           eng        635            783                  56
# 11120  0140131965           eng        415            820                  95
# 11121  0060878827           eng        434            769                 139
# 11122  8497646983           spa        272            113                  12
#
#       publication_date        publisher
# 0            9/16/2006  Scholastic Inc.
# 1             9/1/2004  Scholastic Inc.
# 2            11/1/2003       Scholastic
# 3             5/1/2004  Scholastic Inc.
# 4            9/13/2004       Scholastic
# ...                ...              ...
# 11118       12/21/2004    Da Capo Press
# 11119        12/1/1988    Penguin Books
# 11120         8/1/1993    Penguin Books
# 11121        2/27/2007             Ecco
# 11122        5/28/2006    Edimat Libros
#
# [11123 rows x 10 columns]

# %%
continuousVars2 = ['average_rating', 'num_pages', 'ratings_count', 'text_reviews_count']
df[continuousVars2].describe()
# Out:
#        average_rating     num_pages  ratings_count  text_reviews_count
# count    11123.000000  11123.000000   1.112300e+04        11123.000000
# mean         3.934075    336.405556   1.794285e+04          542.048099
# std          0.350485    241.152626   1.124992e+05         2576.619589
# min          0.000000      0.000000   0.000000e+00            0.000000
# 25%          3.770000    192.000000   1.040000e+02            9.000000
# 50%          3.960000    299.000000   7.450000e+02           47.000000
# 75%          4.140000    416.000000   5.000500e+03          238.000000
# max          5.000000   6576.000000   4.597666e+06        94265.000000

# %% [markdown]
# ### Plots & Histograms
#
# The aim of this section is to provide a visual analysis of the continuous variables in the data frame to identify any potenital outliers.

# %%
fig1 = plt.figure(figsize = (20,20))
ax = fig1.gca()
df[continuousVars2].hist(ax = ax)
plt.show()
# Out:
# C:\Users\Ayanaba\AppData\Local\Temp\ipykernel_31676\1222733508.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df[continuousVars2].hist(ax = ax)

# %% [markdown]
# To further understand the data better, a density curve can be added to the histograms to shed some light on the distribution type

# %%
sns.histplot(x = 'average_rating', data = df, kde = True)
# Out:
# <Axes: xlabel='average_rating', ylabel='Count'>

# %% [markdown]
# From the Histogram we can see that Average Rating has an expected normal distribution.

# %%
sns.histplot(x = 'num_pages', data = df, kde = True)
# Out:
# <Axes: xlabel='num_pages', ylabel='Count'>

# %% [markdown]
# We can also see that the distribution for number of pages is skewed to the left.

# %%
plt.hist(df["ratings_count"], bins= 25)
plt.yscale("log")
plt.show()

# %%
sns.histplot(x = 'ratings_count', data = df, kde = True)
plt.ylim(0,1000)
# Out:
# (0.0, 1000.0)

# %% [markdown]
# The histogram shows that, rating count is left skewed and may include extreme values

# %%
sns.histplot(x = 'text_reviews_count', data = df, kde = True)
plt.ylim(0,1500)
# Out:
# (0.0, 1500.0)

# %% [markdown]
# The histogram also shows that, text reviews count is left skewed and may also include extreme values

# %% [markdown]
# #### To Further Investigate extreme values and outliers, we can visualise the data with Boxplots.

# %%
plt.figure(figsize = (10, 10))
df.boxplot(column= ['average_rating', 'num_pages', 'ratings_count', 'text_reviews_count'])
plt.show()

# %% [markdown]
# We can see that we have some outliers for ratings_count very close to the 5x10^6 range, the outliers can be removed to see to see the effects on the box plot.

# %%
df2 = df[(df['ratings_count'] < 1000)]
plt.figure(figsize = (10, 10))
df2.boxplot(column= ['average_rating', 'num_pages', 'ratings_count', 'text_reviews_count'])
plt.show()

# %% [markdown]
# In order to be able to properly  view the variables on the same scale we have to normalise the data.

# %%
Normalized_Vars = df[['average_rating', 'num_pages', 'ratings_count', 'text_reviews_count']].values.astype(float)
range_Scaler = preprocessing.MinMaxScaler()
Scaled_Vars = range_Scaler.fit_transform(Normalized_Vars)
df_normalized = pd.DataFrame(Scaled_Vars)
plt.figure(figsize = (10, 10))
df_normalized.boxplot()
plt.show()

# %% [markdown]
# The results is inline with our expectactions and fits our four variables on the same scake. It also shows that many of the data points fall outside the Inter Quartile Range, min and max values.

# %% [markdown]
# #### Finally, lets take a look at the categorical variables in the data

# %%
categoricalVars = ['title', 'authors', 'isbn', 'language_code', 'publisher']
df[categoricalVars].describe()
# Out:
#             title       authors        isbn language_code publisher
# count       11123         11123       11123         11123     11123
# unique      10348          6639       11123            27      2290
# top     The Iliad  Stephen King  0439785960           eng   Vintage
# freq            9            40           1          8908       318

# %% [markdown]
# From the results, we can conclude a few details;
#
# - The most frequently occuring book title is 'The lliad' (9).
# - The author with the most books (40) is Stephen King.
# - Majority of the books are written in English (8908/11123).
# - The most frequently occuring publisher is Vintage (318).

# %% [markdown]
# ### Data Exploration & Feature Selection

# %% [markdown]
# To better analyse the data, we need to explore it further. Below, we will explore questions like, which books received the most ratings? Which authors wrote the most books? Who are the top rated authors and so on.

# %% [markdown]
# ##### Which Authors wrote the most books?

# %%
allAuthors = df.authors.unique()
y_pos = np.arange(len(allAuthors))

print(len(allAuthors))

top10Authors = df[['authors', 'title']].groupby(['authors']).count()
top10Authors = top10Authors.sort_values(by=['title'], ascending=True)
top10Authors = top10Authors.tail(10)
top10Authors
# Out:
# 6639
#                   title
# authors
# James Patterson      23
# Dick Francis         28
# Sandra Brown         29
# Mercedes Lackey      29
# Piers Anthony        30
# Agatha Christie      33
# Orson Scott Card     35
# Rumiko Takahashi     39
# Stephen King         40
# P.G. Wodehouse       40

# %%
plt.figure(figsize=(12, 8))
y_NoTitles = top10Authors['title']
plt.barh(top10Authors.index.values, y_NoTitles, 0.8, align='center', alpha=0.5, color = ['#00C5CD', '#000000'])
plt.xlabel('Number of Books')
plt.title('Top 10 Authors (Number of books)')
plt.show()

# %% [markdown]
# We can see that Stephen King & P.G Wodehouse both wrote the highest number of books (40)

# %% [markdown]
# ##### Which Authors performed the best and which performed the worst?
#
# The aim of the model is to predict future performance, the variable used to measure performance in the data is 'average rating'. Therefore, an emphasis shall be placed on exploring the relationship between 'average rating' and other variables.

# %%
GoodRating = 4
GoodRatedAuthors = df[df['average_rating']>=GoodRating]

top10GoodAuthors = GoodRatedAuthors[['authors', 'title']].groupby(['authors']).count()
top10GoodAuthors = top10GoodAuthors.sort_values(by=['title'], ascending=True)
top10GoodAuthors = top10GoodAuthors.tail(10)
top10GoodAuthors
# Out:
#                      title
# authors
# Tite Kubo               14
# Agatha Christie         14
# Laurell K. Hamilton     15
# Dr. Seuss               15
# J.R.R. Tolkien          17
# Stephen King            18
# Terry Pratchett         18
# Mercedes Lackey         19
# P.G. Wodehouse          34
# Rumiko Takahashi        36

# %%
plt.figure(figsize=(12, 8))
y_NoTitles = top10GoodAuthors['title']
plt.barh(top10GoodAuthors.index.values, y_NoTitles, 0.8, align='center', alpha=0.5, color = ['#00C5CD', '#000000'])
plt.xlabel('Number of Books')
plt.title('Best Rated Authors (Number of Books with avg rating > 4)')
plt.show()

# %%
BadRating = 2
BadRatedAuthors = df[df['average_rating'] <= BadRating]

worst10Authors = BadRatedAuthors[['authors', 'title']].groupby(['authors']).count()
worst10Authors = worst10Authors.sort_values(by=['title'], ascending=True)
worst10Authors = worst10Authors.tail(5)
worst10Authors
# Out:
#                                  title
# authors
# Apollodorus/Richard Wagner           1
# Anthony E. Wolf                      1
# Jasmine C.M. Luk/Angel M.Y. Lin      1
# Warren G. Bennis                     1
# Frederick P. Lenz                    2

# %%
plt.figure(figsize=(12, 8))
y_NoTitles = worst10Authors['title']
plt.barh(worst10Authors.index.values, y_NoTitles, 0.8, align='center', alpha=0.5, color = ['#00C5CD', '#000000'])
plt.xlabel('Number of Books')
plt.title('Worst Rated Authors (Number of Books with avg rating < 2)')
plt.show()

# %%
pd.DataFrame(df.groupby(['authors'])['average_rating'].mean().head(10)).sort_values(by=['average_rating'],ascending=False)
# Out:
#                                                     average_rating
# authors
# A.E. Cunningham/Harlan Ellison/Charles F. Mille...           4.150
# Abigail Adams/Frank Shuffelton                               4.140
# Abdul Rahman Munif/Peter Theroux                             4.130
# Abbie Hoffman/Anita Hoffman                                  3.960
# A.S. Byatt                                                   3.770
# A.D.P. Briggs/Leo Tolstoy/Fyodor Dostoyevsky                 3.760
# A.J. Jacobs                                                  3.760
# A.N. Roquelaure/Anne Rice                                    3.735
# A.B. Yehoshua/Hillel Halkin                                  3.600
# A.M. Homes                                                   3.280

# %% [markdown]
# The Author with the highest average rating (4.15/5) is A.E.Cunningham et al.

# %% [markdown]
# #### Which Books Received the Highest Ratings?

# %%
pd.DataFrame(df.groupby(['title'])['average_rating'].mean().head(10)).sort_values(by=['average_rating'],ascending=False)
# Out:
#                                                     average_rating
# title
# 100 Years of Lynchings                                     4.61000
# 100 Love Sonnets                                           4.39000
# 1000 Rings: Inspiring Adornments for the Hand              4.23000
#   said the shotgun to the head.                            4.22000
# 'Salem's Lot                                               4.04875
# 100 Great Fantasy Short Short Stories                      3.91000
# 10 lb Penalty                                              3.90000
# 1 000 Places to See Before You Die                         3.85000
# 1000 Record Covers                                         3.85000
# $30 Film School: How to Write  Direct  Produce ...         3.49000

# %% [markdown]
# The Title with the highest average rating (4.61/5) is 100 Years of Lynchings

# %% [markdown]
# #### Which Publisher Received the Highest Ratings?

# %%
pd.DataFrame(df.groupby(['publisher'])['average_rating'].mean().head(10)).sort_values(by=['average_rating'],ascending=False)
# Out:
#                                average_rating
# publisher
# A K PETERS                              4.500
# AA World Services                       4.450
# A & C Black (Childrens books)           4.400
# 1st World Library                       4.180
# A Harvest Book/Harcourt  Inc.           4.070
# ADV Manga                               4.038
# AHA! Process                            3.900
# 10/18                                   3.650
# 1st Book Library                        3.580
# ACE                                     3.560

# %% [markdown]
# #### Which House Published the Most Books?

# %%
allPublishers = df.publisher.unique()
y_pos = np.arange(len(allPublishers))

print(len(allPublishers))

top10Publishers = df[['publisher', 'title']].groupby(['publisher']).count()
top10Publishers = top10Publishers.sort_values(by=['title'], ascending=True)
top10Publishers = top10Publishers.tail(10)
top10Publishers
# Out:
# 2290
#                   title
# publisher
# VIZ Media LLC        88
# Bantam              110
# Pocket Books        111
# HarperCollins       112
# Harper Perennial    112
# Ballantine Books    144
# Mariner Books       150
# Penguin Classics    184
# Penguin Books       261
# Vintage             318

# %%
plt.figure(figsize=(12, 8))
y_NoTitles = top10Publishers['title']
plt.barh(top10Publishers.index.values, y_NoTitles, 0.8, align='center', alpha=0.5, color = ['#00C5CD', '#000000'])
plt.xlabel('Number of Books')
plt.title('Top 10 Publishing Houses with most number of books')
plt.show()

# %% [markdown]
# ##### Top 10 Rated Publishers

# %%
GoodRatedPublishers = df[df['average_rating']>=GoodRating]

top10GoodPublishers = GoodRatedPublishers[['publisher', 'title']].groupby(['publisher']).count()
top10GoodPublishers = top10GoodPublishers.sort_values(by=['title'], ascending=True)
top10GoodPublishers = top10GoodPublishers.tail(10)

plt.figure(figsize=(12, 8))
y_NoTitles = top10GoodPublishers['title']
plt.barh(top10GoodPublishers.index.values, y_NoTitles, 0.8, align='center', alpha=0.5, color = ['#00C5CD', '#000000'])
plt.xlabel('Number of Books')
plt.title('Best Rated Publsihers (Number of Books with avg rating > 4)')
plt.show()

# %% [markdown]
# #### Which Titles accrued the most ratings

# %%
top10Titles = df.nlargest(10, ['ratings_count'])
top10TitlesG = top10Titles[['title', 'ratings_count']]
top10TitlesG = top10TitlesG.sort_values(by=['ratings_count'], ascending=True)

plt.figure(figsize=(12, 8))
y_NoTitles = top10TitlesG['title']
plt.barh(y_NoTitles, top10TitlesG.ratings_count, 0.8, align='center', alpha=0.5, color = ['#00C5CD', '#000000'])
plt.xlabel('Number of Ratings')
plt.title('Top 10 Books (Number of Ratings)')
plt.show()

# %% [markdown]
# We see that Twilight #1 accrued the most ratings approaching a count number of nearly 5 million

# %% [markdown]
# ### Further Exploration
#
# To better understand the relationships between the variables, we can check the correlation amonsgt variables.

# %%
g = sns.PairGrid(df,diag_sharey = False, corner = True)
g.map_lower(plt.scatter, alpha = 0.6)

# %%
corr = df.corr()
corr
# Out:
# C:\Users\Ayanaba\AppData\Local\Temp\ipykernel_31676\2438084875.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
#                       bookID  average_rating    isbn13  num_pages  \
# bookID              1.000000       -0.036207 -0.002185  -0.026134
# average_rating     -0.036207        1.000000 -0.001965   0.150477
# isbn13             -0.002185       -0.001965  1.000000  -0.009818
# num_pages          -0.026134        0.150477 -0.009818   1.000000
# ratings_count      -0.076820        0.038224  0.005494   0.034337
# text_reviews_count -0.081289        0.033663  0.008152   0.036977
#
#                     ratings_count  text_reviews_count
# bookID                  -0.076820           -0.081289
# average_rating           0.038224            0.033663
# isbn13                   0.005494            0.008152
# num_pages                0.034337            0.036977
# ratings_count            1.000000            0.865977
# text_reviews_count       0.865977            1.000000

# %%
sns.heatmap(corr, annot= True, fmt=".2f", linewidths=.5, cmap="crest")
# Out:
# <Axes: >

# %% [markdown]
# To Conclude, we can now tell that;
#
# - 'ratings_count' & 'text_reviews_count' have a high correlation factor of 0.87.
# - There are no other significant correlations, with the second two most correlated variables being 'num_pages' & 'average_rating' at 0.15.
#
# Since no single variable has a signigificant correlation with 'average_rating', we shall explore the influence of 'ratings_count' & 'text_reviews_count' combined on averagte rating.

# %% [markdown]
# ### Exploring Text Reviews and Rating Counts.

# %% [markdown]
# ##### Did the books with a high number of text reviews recieve higher ratings?

# %%
data_TextReviewsGreaterThan5K = df[df['text_reviews_count'] > 5000]

sns.jointplot(data=data_TextReviewsGreaterThan5K, x="text_reviews_count", y="average_rating", kind="reg")

# %% [markdown]
# From the results, we observe that as the text review count increases, the average rating increases slightly as well. However, we cannot call it a strong correlation.

# %% [markdown]
# ##### Did the books with a high number of reviews recieve higher ratings?

# %%
data_ReviewsGreaterThan1M = df[df['ratings_count'] > 1000000]

sns.jointplot(data=data_ReviewsGreaterThan1M, x="ratings_count", y="average_rating", kind="reg")

# %% [markdown]
# There is no correlation(if not ever so sightly negative) between books with a high number of reviews (rating counts) and average rating.

# %% [markdown]
# ### Book Distribution by Language

# %%
sns.set_context('paper')
plt.figure(figsize=(10,10))
ax = df.groupby('language_code')['title'].count().plot.bar()
plt.title('Language Code')
plt.xticks(fontsize = 15)
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x()-0.3, p.get_height()+100))
plt.show()

# %% [markdown]
# We can see that Majority of the books are in 'eng';
# - that only 7 languages have a book count of > 45.
# - ~95% of the books fall into 7 languages.
#
#
# Lets look at the % spread amongst those 7 languages.

# %%
df['language_code'].value_counts().head(7).plot(kind = 'pie', figsize=(10, 10), autopct = '%1.1f%%').legend()
plt.show()

# %% [markdown]
# ### Feature Engineering
#
# Before we beging the Feature Engineering, we are going to drop some columns. The columns dropped contain information that can be expected to have little bearing on the future performance of a book such as ISBN.
#
# 'Title' has also been dropped, however Author shall be maintained as I am going in with the assumption that the reputation of an author can have an effect on the performance of future book titles.

# %%
df3 = df.drop(['bookID', 'isbn', 'isbn13', 'publication_date', 'publisher'],axis=1)

# %%
df_index_ChosenLangs = df3.loc[df3['language_code'].isin(['eng','en-US', 'spa', 'en-GB', 'fre'])] 
df_index_ChosenLangs.head()
# Out:
#                                                title  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...
# 1  Harry Potter and the Order of the Phoenix (Har...
# 2  Harry Potter and the Chamber of Secrets (Harry...
# 3  Harry Potter and the Prisoner of Azkaban (Harr...
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
#
#                       authors  average_rating language_code  num_pages  \
# 0  J.K. Rowling/Mary GrandPré            4.57           eng        652
# 1  J.K. Rowling/Mary GrandPré            4.49           eng        870
# 2                J.K. Rowling            4.42           eng        352
# 3  J.K. Rowling/Mary GrandPré            4.56           eng        435
# 4  J.K. Rowling/Mary GrandPré            4.78           eng       2690
#
#    ratings_count  text_reviews_count
# 0        2095690               27591
# 1        2153167               29221
# 2           6333                 244
# 3        2339585               36325
# 4          41428                 164

# %% [markdown]
# To Start with we are going to split the data into two sets, based on ratings count.
#
# We will set the threshold at >= 100,00 ratings. Therefore, we will drop all entries with a rating count below 100,00 into a different Dataframe.

# %%
HighRating = 100000
HighRatedBooks = df_index_ChosenLangs.drop(df_index_ChosenLangs.index[df_index_ChosenLangs['ratings_count'] <= HighRating])

# %%
HighRatedBooks._is_view
# Out:
# False

# %%
HighRatedBooks.shape
# Out:
# (352, 7)

# %%
HighRatedBooks.head()
# Out:
#                                                 title  \
# 0   Harry Potter and the Half-Blood Prince (Harry ...
# 1   Harry Potter and the Order of the Phoenix (Har...
# 3   Harry Potter and the Prisoner of Azkaban (Harr...
# 8   The Ultimate Hitchhiker's Guide to the Galaxy ...
# 12               A Short History of Nearly Everything
#
#                        authors  average_rating language_code  num_pages  \
# 0   J.K. Rowling/Mary GrandPré            4.57           eng        652
# 1   J.K. Rowling/Mary GrandPré            4.49           eng        870
# 3   J.K. Rowling/Mary GrandPré            4.56           eng        435
# 8                Douglas Adams            4.38           eng        815
# 12                 Bill Bryson            4.21           eng        544
#
#     ratings_count  text_reviews_count
# 0         2095690               27591
# 1         2153167               29221
# 3         2339585               36325
# 8          249558                4080
# 12         248558                9396

# %%
OtherBooks = df_index_ChosenLangs.drop(df_index_ChosenLangs.index[df_index_ChosenLangs['ratings_count'] > HighRating])

# %%
OtherBooks.shape
# Out:
# (10540, 7)

# %%
OtherBooks.head()
# Out:
#                                                title  \
# 2  Harry Potter and the Chamber of Secrets (Harry...
# 4  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# 5  Unauthorized Harry Potter Book Seven News: "Ha...
# 6       Harry Potter Collection (Harry Potter  #1-6)
# 7  The Ultimate Hitchhiker's Guide: Five Complete...
#
#                       authors  average_rating language_code  num_pages  \
# 2                J.K. Rowling            4.42           eng        352
# 4  J.K. Rowling/Mary GrandPré            4.78           eng       2690
# 5      W. Frederick Zimmerman            3.74         en-US        152
# 6                J.K. Rowling            4.73           eng       3342
# 7               Douglas Adams            4.38           eng        815
#
#    ratings_count  text_reviews_count
# 2           6333                 244
# 4          41428                 164
# 5             19                   1
# 6          28242                 808
# 7           3628                 254

# %% [markdown]
# ### Encoding the Categorical variables for the two samples

# %%
labelEncode = preprocessing.LabelEncoder()

# %% [markdown]
# Encode the 'title'
#
# Encoding samples in HighRatedBooks

# %%
# encode title column
HighRatedBooks['title'] = labelEncode.fit_transform(HighRatedBooks['title'])
HighRatedBooks.head()
# Out:
#     title                     authors  average_rating language_code  \
# 0      98  J.K. Rowling/Mary GrandPré            4.57           eng
# 1      99  J.K. Rowling/Mary GrandPré            4.49           eng
# 3     100  J.K. Rowling/Mary GrandPré            4.56           eng
# 8     313               Douglas Adams            4.38           eng
# 12     19                 Bill Bryson            4.21           eng
#
#     num_pages  ratings_count  text_reviews_count
# 0         652        2095690               27591
# 1         870        2153167               29221
# 3         435        2339585               36325
# 8         815         249558                4080
# 12        544         248558                9396

# %%
OtherBooks['title'] = labelEncode.fit_transform(OtherBooks['title'])
OtherBooks.head()
# Out:
#    title                     authors  average_rating language_code  num_pages  \
# 2   2925                J.K. Rowling            4.42           eng        352
# 4   2920  J.K. Rowling/Mary GrandPré            4.78           eng       2690
# 5   9322      W. Frederick Zimmerman            3.74         en-US        152
# 6   2921                J.K. Rowling            4.73           eng       3342
# 7   8765               Douglas Adams            4.38           eng        815
#
#    ratings_count  text_reviews_count
# 2           6333                 244
# 4          41428                 164
# 5             19                   1
# 6          28242                 808
# 7           3628                 254

# %% [markdown]
# ##### Encode the 'authors'
# Encoding samples in HighRatedBooks

# %%
HighRatedBooks['authors'] = labelEncode.fit_transform(HighRatedBooks['authors'])
HighRatedBooks.head()
# Out:
#     title  authors  average_rating language_code  num_pages  ratings_count  \
# 0      98       90            4.57           eng        652        2095690
# 1      99       90            4.49           eng        870        2153167
# 3     100       90            4.56           eng        435        2339585
# 8     313       55            4.38           eng        815         249558
# 12     19       26            4.21           eng        544         248558
#
#     text_reviews_count
# 0                27591
# 1                29221
# 3                36325
# 8                 4080
# 12                9396

# %% [markdown]
# Encoding samples in df_OtherBooks

# %%
OtherBooks['authors'] = labelEncode.fit_transform(OtherBooks['authors'])
OtherBooks.head()
# Out:
#    title  authors  average_rating language_code  num_pages  ratings_count  \
# 2   2925     2544            4.42           eng        352           6333
# 4   2920     2546            4.78           eng       2690          41428
# 5   9322     6117            3.74         en-US        152             19
# 6   2921     2544            4.73           eng       3342          28242
# 7   8765     1429            4.38           eng        815           3628
#
#    text_reviews_count
# 2                 244
# 4                 164
# 5                   1
# 6                 808
# 7                 254

# %% [markdown]
# #### Dummy encode the 'language_code'
# Encoding samples in df_HighRatedBooks

# %%
encoded_lang_high = pd.get_dummies(HighRatedBooks['language_code'])
colsExist2 = HighRatedBooks.columns.isin(['eng','en-US', 'spa', 'en-GB', 'fre']).any()
if  colsExist2 == False:
    HighRatedBooks = pd.concat([HighRatedBooks, encoded_lang_high], axis = 1)
print(HighRatedBooks.shape)
HighRatedBooks.head()
# Out:
# (352, 12)
#     title  authors  average_rating language_code  num_pages  ratings_count  \
# 0      98       90            4.57           eng        652        2095690
# 1      99       90            4.49           eng        870        2153167
# 3     100       90            4.56           eng        435        2339585
# 8     313       55            4.38           eng        815         249558
# 12     19       26            4.21           eng        544         248558
#
#     text_reviews_count  en-GB  en-US  eng  fre  spa
# 0                27591      0      0    1    0    0
# 1                29221      0      0    1    0    0
# 3                36325      0      0    1    0    0
# 8                 4080      0      0    1    0    0
# 12                9396      0      0    1    0    0

# %% [markdown]
# Encoding samples in df_OtherBooks

# %%
encoded_lang_other = pd.get_dummies(OtherBooks['language_code'])
encoded_lang_other.head()
colsExist = OtherBooks.columns.isin(['eng','en-US', 'spa', 'en-GB', 'fre']).any()
if  colsExist == False:
    OtherBooks = pd.concat([OtherBooks, encoded_lang_other], axis = 1)
print(OtherBooks.shape)
OtherBooks.head()
# Out:
# (10540, 12)
#    title  authors  average_rating language_code  num_pages  ratings_count  \
# 2   2925     2544            4.42           eng        352           6333
# 4   2920     2546            4.78           eng       2690          41428
# 5   9322     6117            3.74         en-US        152             19
# 6   2921     2544            4.73           eng       3342          28242
# 7   8765     1429            4.38           eng        815           3628
#
#    text_reviews_count  en-GB  en-US  eng  fre  spa
# 2                 244      0      0    1    0    0
# 4                 164      0      0    1    0    0
# 5                   1      0      1    0    0    0
# 6                 808      0      0    1    0    0
# 7                 254      0      0    1    0    0

# %% [markdown]
# ### Building a Linear Regression Model

# %% [markdown]
# #### Preparing the Data & Standardising the dataset

# %% [markdown]
# First we will divide the data into attributes and labels and then we will split 80% of the data to the training set and 20% of the data to test set

# %%
def ModelBuilding_LinearRegression(df_Current, testSize=0.2):
    X = df_Current.drop(['average_rating', 'language_code'], axis = 1)
    y = df_Current['average_rating']
    
    print("Shape of Inputs = {0}".format(X.shape))
    print("Shape of Target = {0}".format(y.shape))

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = testSize, random_state = 999)
    linReg = LinearRegression()
    linReg.fit(X_train, y_train)
    
    print("Intercept = {0}".format(linReg.intercept_))
    print("Coefficients = {0}".format(linReg.coef_.tolist()))

    predictions = linReg.predict(X_test)
    return (predictions, X_test, y_test, linReg)

# %% [markdown]
# #### Model Intercept, coefficients and "average_rating" predictions for Highly rated books

# %%
Pedicted_Scores, X_test, y_test, linReg = ModelBuilding_LinearRegression(HighRatedBooks)
# Out:
# Shape of Inputs = (352, 10)
# Shape of Target = (352,)
# Intercept = 3.9325826624379228
# Coefficients = [-0.00016464624946778465, -0.0003636180745723853, 0.00020836290047307815, 1.4808442164843786e-08, -9.62471452559667e-07, 2.7755575615628914e-17, 0.10593488231414339, 0.0869891553754818, -0.258690445893689, 0.06576640820406404]

# %%
Actual_Predicted = pd.DataFrame({'Observed': y_test.tolist(), 'Predicted': Pedicted_Scores.tolist()})
Actual_Predicted['diff'] = Actual_Predicted['Observed'] - Actual_Predicted['Predicted']
Actual_Predicted.head(10)
# Out:
#    Observed  Predicted      diff
# 0      3.68   3.951289 -0.271289
# 1      4.23   4.079815  0.150185
# 2      3.67   3.998640 -0.328640
# 3      4.00   4.014479 -0.014479
# 4      4.08   4.135671 -0.055671
# 5      4.25   4.024921  0.225079
# 6      4.31   4.037478  0.272522
# 7      3.70   4.011702 -0.311702
# 8      4.13   3.977453  0.152547
# 9      4.35   4.048087  0.301913

# %%
sns.lmplot(x="Observed", y="Predicted", data=Actual_Predicted);

# %%
# evaluate the performance of the algorithm
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test, Pedicted_Scores))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test, Pedicted_Scores))
print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test, Pedicted_Scores)))
print('Mean Absolute Error (MAE):', np.sum(abs(Actual_Predicted['diff']))/Actual_Predicted.shape[0])
# Out:
# Mean Absolute Error (MAE): 0.18223331593534398
# Mean Squared Error (MSE): 0.05092396471944311
# Root Mean Squared Error (RMSE): 0.2256633880793318
# Mean Absolute Error (MAE): 0.18223331593534398

# %% [markdown]
# The model looks reasonable with Root Mean Square Error (RMSE) at around 0.22 and Mean Absolute Error (MAE) around 0.18

# %% [markdown]
# #### Model Intercept, coefficients and "average_rating" predictions for Other books not highly rated (i.e. with ratings < 100,000)

# %%
X2 = OtherBooks.drop(['average_rating', 'language_code'], axis = 1)
y2 = OtherBooks['average_rating']
print(X2.shape)
print(y2.shape)
# Out:
# (10540, 10)
# (10540,)

# %%
Pedicted_Scores, X_test, y_test, linReg = ModelBuilding_LinearRegression(OtherBooks)
# Out:
# Shape of Inputs = (10540, 10)
# Shape of Target = (10540,)
# Intercept = 3.840321201955307
# Coefficients = [2.0389991680863785e-06, 3.1173364214406863e-06, 0.00021689074768087397, 3.6646938803323656e-06, -6.433433430393544e-05, 0.0017925414248180806, -0.020550763535307697, -0.010880069524687508, 0.03667486582786008, -0.007036574192682979]

# %%
Actual_Predicted = pd.DataFrame({'Observed': y_test.tolist(), 'Predicted': Pedicted_Scores.tolist()})
Actual_Predicted['diff'] = Actual_Predicted['Observed'] - Actual_Predicted['Predicted']
Actual_Predicted.head(10)
# Out:
#    Observed  Predicted      diff
# 0      3.95   3.921961  0.028039
# 1      4.25   3.954450  0.295550
# 2      3.79   3.895943 -0.105943
# 3      3.93   3.879794  0.050206
# 4      4.46   3.958621  0.501379
# 5      4.32   3.979768  0.340232
# 6      3.71   3.898859 -0.188859
# 7      3.80   3.906240 -0.106240
# 8      3.87   3.878851 -0.008851
# 9      3.95   3.908431  0.041569

# %%
sns.lmplot(x="Observed", y="Predicted", data=Actual_Predicted);

# %%
# evaluate the performance of the algorithm
print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test, Pedicted_Scores))
print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test, Pedicted_Scores))
print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test, Pedicted_Scores)))
# Out:
# Mean Absolute Error (MAE): 0.2235900679776171
# Mean Squared Error (MSE): 0.10144386489246
# Root Mean Squared Error (RMSE): 0.31850253514290905

# %% [markdown]
# The model still looks reasonable, albiet slightly worse with Root Mean Square Error (RMSE) of approx. 0.32 and Mean Absolute Error (MAE) around 0.22

# %% [markdown]
# Mocked Up Case

# %%
Mocked_Case = np.array([8, 27, 219, 325003, 3240, 0, 0, 1, 0, 0])

# %%
Score_Mocked_Case = linReg.predict(Mocked_Case.reshape(1, -1))
# Out:
# c:\Users\Ayanaba\.conda\envs\MachineLearningProject\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
Predictions = pd.DataFrame({'Observed': y_test.iloc[0], 'Predicted': Score_Mocked_Case})
Predictions
# Out:
#    Observed  Predicted
# 0      3.68   4.055763

# %% [markdown]
# Tested a mocked up case for deployment (prediction accuracy seems very close for this case, around 90%)

# %%
Scores2 = linReg.predict(X2)

# %%
DeployedModelPredictions = pd.DataFrame({'Observed': y2.tolist(), 'Predicted': Scores2.tolist()})
DeployedModelPredictions['diff'] = DeployedModelPredictions['Observed'] - DeployedModelPredictions['Predicted']
DeployedModelPredictions.head(10)
# Out:
#    Observed  Predicted      diff
# 0      4.42   2.686140  1.733860
# 1      4.78   3.173985  1.606015
# 2      3.74   0.311104  3.428896
# 3      4.73   3.309585  1.420415
# 4      4.38   2.226462  2.153538
# 5      4.22   2.311354  1.908646
# 6      4.22   2.266133  1.953867
# 7      4.38   2.226673  2.153327
# 8      3.44   3.663559 -0.223559
# 9      3.87   3.667684  0.202316

# %%
sns.lmplot(x="Observed", y="Predicted", data=DeployedModelPredictions);

# %%
print('Mean Absolute Error (MAE):', np.sum(abs(DeployedModelPredictions['diff']))/DeployedModelPredictions.shape[0])
# Out:
# Mean Absolute Error (MAE): 1.8518828753473577

# %% [markdown]
# The model built for df_HighRatedBooks performs worse on df_OtherBooks with a Mean Absolute Error (MAE) 1.196
